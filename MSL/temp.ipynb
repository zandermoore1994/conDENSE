# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.load("A-4_labels.npy").shape
# Out:
# (8080,)

# %%
np.save("A-3_labels.npy", np.load("A-3_labels.npy")[:, 0])

# %%
np.load("P-2_labels.npy")[:, 0]

# %%
np.save("../SMD/machine-3-7_labels.npy", np.load("../SMD/machine-3-7_labels.npy")[:, 0])

# %%
np.load("../SMD/machine-2-1_train.npy").shape
# Out:
# (23693, 38)

# %%
np.load("../SMD/machine-2-1_test.npy").shape
# Out:
# (23694, 38)

# %%
plt.plot(np.load("../SMD/machine-3-7_test.npy"))
plt.show()

# %%
plt.plot(np.load("../SMD/machine-1-1_train.npy"))
plt.show()
